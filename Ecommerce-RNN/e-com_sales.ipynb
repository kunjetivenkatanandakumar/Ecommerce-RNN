# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/datasets/kvenkatanandakumar/ecommerce-rnn/Ecommerce-RNN/ecom_sales_data.csv")

print(df.head())
# Out:
#          Date  Sales
# 0  2024-01-01  120.0
# 1  2024-01-02  126.0
# 2  2024-01-03  132.0
# 3  2024-01-04  132.0
# 4  2024-01-05  134.0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

sales = scaler.fit_transform(df[['Sales']])

# %%
import numpy as np

X = []
y = []

time_step = 3

for i in range(len(sales)-time_step):
    X.append(sales[i:i+time_step])
    y.append(sales[i+time_step])

X = np.array(X)
y = np.array(y)

print(X.shape)
# Out:
# (997, 3, 1)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

model = Sequential()

model.add(
    SimpleRNN(
        units=32,
        activation='tanh',
        input_shape=(3,1)
    )
)

model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mse'
)

model.summary()
# Out:
# 2026-06-16 06:51:13.988710: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781592674.242235      58 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781592674.316391      58 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781592674.993004      58 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
history = model.fit(
    X,
    y,
    epochs=50,
    batch_size=2
)
# Out:
# Epoch 1/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.0054
# Epoch 2/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6148e-04
# Epoch 3/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.3697e-04
# Epoch 4/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 6.0792e-05
# Epoch 5/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.6919e-05
# Epoch 6/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.0782e-05
# Epoch 7/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.9204e-05
# Epoch 8/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.4850e-04
# Epoch 9/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6076e-05
# Epoch 10/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2784e-04
# Epoch 11/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.4867e-05
# Epoch 12/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.9076e-05
# Epoch 13/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.2706e-04
# Epoch 14/50
# ...

# %%
model.save("sales_rnn_model.keras")

print("Model Saved")
# Out:
# Model Saved
