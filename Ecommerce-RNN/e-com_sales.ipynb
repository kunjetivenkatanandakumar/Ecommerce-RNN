# %%
import pandas as pd

df = pd.read_csv("/kaggle/input/datasets/kvenkatanandakumar/ecommerce-rnn/Ecommerce-RNN/ecom_sales_data.csv")

print(df.head())
# Out:
#          Date  Sales
# 0  2024-01-01  120.0
# 1  2024-01-02  126.0
# 2  2024-01-03  132.0
# 3  2024-01-04  132.0
# 4  2024-01-05  134.0

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

sales = scaler.fit_transform(df[['Sales']])

# %%
import numpy as np

X = []
y = []

time_step = 3

for i in range(len(sales)-time_step):
    X.append(sales[i:i+time_step])
    y.append(sales[i+time_step])

X = np.array(X)
y = np.array(y)

print(X.shape)
# Out:
# (997, 3, 1)

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

model = Sequential()

model.add(
    SimpleRNN(
        units=32,
        activation='tanh',
        input_shape=(3,1)
    )
)

model.add(Dense(1))

model.compile(
    optimizer='adam',
    loss='mse'
)

model.summary()
# Out:
# 2026-06-16 06:56:07.363922: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1781592967.616753      16 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1781592967.685824      16 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1781592968.254414      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781592968.254458      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781592968.254461      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1781592968.254464      16 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-06-16 06:56:24.270817: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)          │ (None, 32)             │         1,088 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,121 (4.38 KB)
#  Trainable params: 1,121 (4.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X,
    y,
    epochs=50,
    batch_size=2
)
# Out:
# Epoch 1/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - loss: 0.0043
# Epoch 2/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0231e-04
# Epoch 3/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 9.0916e-05
# Epoch 4/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.5432e-05
# Epoch 5/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6860e-05
# Epoch 6/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.8314e-05
# Epoch 7/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.2788e-05
# Epoch 8/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.6126e-05
# Epoch 9/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.2362e-05
# Epoch 10/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.8680e-05
# Epoch 11/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.3396e-05
# Epoch 12/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.6352e-05
# Epoch 13/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6118e-05
# Epoch 14/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 7.7288e-05
# Epoch 15/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.1538e-05
# Epoch 16/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 3.9807e-05
# Epoch 17/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.6053e-05
# Epoch 18/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 4.6403e-05
# Epoch 19/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2952e-05
# Epoch 20/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.0677e-05
# Epoch 21/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8632e-05
# Epoch 22/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.1810e-05
# Epoch 23/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.9424e-05
# Epoch 24/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6049e-05
# Epoch 25/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7058e-05
# Epoch 26/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.8969e-05
# Epoch 27/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 5.7379e-05
# Epoch 28/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7284e-05
# Epoch 29/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.4218e-05
# Epoch 30/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.6302e-05
# Epoch 31/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.6411e-05
# Epoch 32/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.2844e-05
# Epoch 33/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9185e-05
# Epoch 34/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.7392e-05
# Epoch 35/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7384e-05
# Epoch 36/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5753e-05
# Epoch 37/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.5271e-05
# Epoch 38/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.7211e-05
# Epoch 39/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4671e-05
# Epoch 40/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.4466e-05
# Epoch 41/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9592e-05
# Epoch 42/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7918e-05
# Epoch 43/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.3457e-05
# Epoch 44/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.6865e-05
# Epoch 45/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0416e-05
# Epoch 46/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 3.2897e-05
# Epoch 47/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.5580e-05
# Epoch 48/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.7382e-05
# Epoch 49/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 1.9987e-05
# Epoch 50/50
# 499/499 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 2.0806e-05

# %%
model.save("sales_rnn_model.keras")

print("Model Saved")
# Out:
# Model Saved
